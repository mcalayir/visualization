# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
# Generating new data
np.random.seed(613)
x1 = np.arange(50)
y1 = np.random.randint(0, 75,50)
x2 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y2 = np.array([110, 180, 240, 99, 220])

# %%
fig,(ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(7, 3))
ax1.scatter(x1,y1)
ax1.annotate('This is important',xy=(10,65),xytext=(30,65),arrowprops=dict(facecolor='black'))
ax2.bar(x2,y2)

fig.show()
# Out:
# /var/folders/w5/r4lc7t4n10bcnzk755rdfxq00000gn/T/ipykernel_2706/140958253.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig,someaxes=plt.subplot_mosaic([['ax1','ax3'],['ax2','ax3']],figsize=(7,4))

someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)
plt.show()

# %% [markdown]
# #Set up the axis labels

# %%
fig,someaxes=plt.subplot_mosaic([['ax1','ax3'],['ax2','ax3']],figsize=(7,4),layout='constrained') 

someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)

someaxes["ax1"].set_xlabel('A Big Label',fontsize=18)
someaxes["ax2"].set_xlabel('Another Label',fontsize=18)
someaxes["ax3"].set_xlabel('Label 2: 2 Fast 2 Furious',fontsize=18)
# Out:
# Text(0.5, 0, 'Label 2: 2 Fast 2 Furious')

# %% [markdown]
# #Multiple visualizations on one axis

# %%
# Sample data
x = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])
y2 = np.array([170, 100, 90, 120, 50])

# Define figure and axes 
fig, ax = plt.subplots(figsize=(7, 3))

# Call both bar and plot elements to the same axes
ax.bar(x, y1, color = "indigo")
ax.plot(x, y2, color = "red")

# %% [markdown]
# #Add error bars

# %%
y2_sd = np.std(y2)

fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2, color = "blue")
ax.errorbar(x,y2, color='red',yerr=y2_sd,fmt='none')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
y2_sd = np.std(y2)
fig, ax = plt.subplots(figsize=(7, 3))

ax.errorbar(x,y2, color='red',yerr=y2_sd,fmt='-',ecolor='blue',elinewidth=4,capsize=10,capthick=4,errorevery=3)
# Out:
# <ErrorbarContainer object of 3 artists>
